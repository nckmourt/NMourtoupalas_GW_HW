# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x11f032d68>,
#   <matplotlib.axis.XTick at 0x11f0326d8>,
#   <matplotlib.axis.XTick at 0x11f0323c8>,
#   <matplotlib.axis.XTick at 0x11f0f7a90>,
#   <matplotlib.axis.XTick at 0x11f0f7ef0>,
#   <matplotlib.axis.XTick at 0x11f108400>,
#   <matplotlib.axis.XTick at 0x11f1088d0>,
#   <matplotlib.axis.XTick at 0x11f108dd8>,
#   <matplotlib.axis.XTick at 0x11f110390>,
#   <matplotlib.axis.XTick at 0x11f110908>,
#   <matplotlib.axis.XTick at 0x11f110e80>,
#   <matplotlib.axis.XTick at 0x11f1109e8>,
#   <matplotlib.axis.XTick at 0x11f108978>,
#   <matplotlib.axis.XTick at 0x11f1174a8>,
#   <matplotlib.axis.XTick at 0x11f117a20>,
#   <matplotlib.axis.XTick at 0x11f117e80>,
#   <matplotlib.axis.XTick at 0x11f11d550>,
#   <matplotlib.axis.XTick at 0x11f11dac8>,
#   <matplotlib.axis.XTick at 0x11f1250f0>,
#   <matplotlib.axis.XTick at 0x11f1255f8>,
#   <matplotlib.axis.XTick at 0x11f11d518>,
#   <matplotlib.axis.XTick at 0x11f117550>,
#   <matplotlib.axis.XTick at 0x11f125d30>,
#   <matplotlib.axis.XTick at 0x11f12c128>,
#   <matplotlib.axis.XTick at 0x11f12c630>,
#   <matplotlib.axis.XTick at 0x11f12cba8>,
#   <matplotlib.axis.XTick at 0x11f133198>,
#   <matplotlib.axis.XTick at 0x11f1336d8>,
#   <matplotlib.axis.XTick at 0x11f133c50>,
#   <matplotlib.axis.XTick at 0x11f13a208>,
#   <matplotlib.axis.XTick at 0x11f133780>,
#   <matplotlib.axis.XTick at 0x11f117470>,
#   <matplotlib.axis.XTick at 0x11f13a6a0>,
#   <matplotlib.axis.XTick at 0x11f13ac18>,
#   <matplotlib.axis.XTick at 0x11f1411d0>,
#   <matplotlib.axis.XTick at 0x11f141748>,
#   <matplotlib.axis.XTick at 0x11f141cc0>,
#   <matplotlib.axis.XTick at 0x11f149278>,
#   <matplotlib.axis.XTick at 0x11f1497f0>,
#   <matplotlib.axis.XTick at 0x11f141278>,
#   <matplotlib.axis.XTick at 0x11f13a668>,
#   <matplotlib.axis.XTick at 0x11f149f98>,
#   <matplotlib.axis.XTick at 0x11f1502b0>,
#   <matplotlib.axis.XTick at 0x11f150828>,
#   <matplotlib.axis.XTick at 0x11f150da0>,
#   <matplotlib.axis.XTick at 0x11f157358>,
#   <matplotlib.axis.XTick at 0x11f1578d0>,
#   <matplotlib.axis.XTick at 0x11f157e48>,
#   <matplotlib.axis.XTick at 0x11f15e400>,
#   <matplotlib.axis.XTick at 0x11f1579b0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(433.94444444444446, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/avg_state_rain.png")
plt.show()
